# %%
import pandas as pd

# %%
df = pd.DataFrame()

# %%
df = pd.read_csv('C:/Users/hp/Downloads/earthquake.csv')

# %%
df
# Out:
#              Date      Time  Latitude  Longitude        Type   Depth  \
# 0      01/02/1965  13:44:18   19.2460   145.6160  Earthquake  131.60
# 1      01/04/1965  11:29:49    1.8630   127.3520  Earthquake   80.00
# 2      01/05/1965  18:05:58  -20.5790  -173.9720  Earthquake   20.00
# 3      01/08/1965  18:49:43  -59.0760   -23.5570  Earthquake   15.00
# 4      01/09/1965  13:32:50   11.9380   126.4270  Earthquake   15.00
# ...           ...       ...       ...        ...         ...     ...
# 23407  12/28/2016  08:22:12   38.3917  -118.8941  Earthquake   12.30
# 23408  12/28/2016  09:13:47   38.3777  -118.8957  Earthquake    8.80
# 23409  12/28/2016  12:38:51   36.9179   140.4262  Earthquake   10.00
# 23410  12/29/2016  22:30:19   -9.0283   118.6639  Earthquake   79.00
# 23411  12/30/2016  20:08:28   37.3973   141.4103  Earthquake   11.94
#
#        Depth Error  Depth Seismic Stations  Magnitude Magnitude Type  ...  \
# ...

# %%
df.head()
# Out:
#          Date      Time  Latitude  Longitude        Type  Depth  Depth Error  \
# 0  01/02/1965  13:44:18    19.246    145.616  Earthquake  131.6          NaN
# 1  01/04/1965  11:29:49     1.863    127.352  Earthquake   80.0          NaN
# 2  01/05/1965  18:05:58   -20.579   -173.972  Earthquake   20.0          NaN
# 3  01/08/1965  18:49:43   -59.076    -23.557  Earthquake   15.0          NaN
# 4  01/09/1965  13:32:50    11.938    126.427  Earthquake   15.0          NaN
#
#    Depth Seismic Stations  Magnitude Magnitude Type  ...  \
# 0                     NaN        6.0             MW  ...
# 1                     NaN        5.8             MW  ...
# 2                     NaN        6.2             MW  ...
# 3                     NaN        5.8             MW  ...
# 4                     NaN        5.8             MW  ...
#
#    Magnitude Seismic Stations  Azimuthal Gap  Horizontal Distance  \
# 0                         NaN            NaN                  NaN
# ...

# %%
df.tail(4)
# Out:
#              Date      Time  Latitude  Longitude        Type  Depth  \
# 23408  12/28/2016  09:13:47   38.3777  -118.8957  Earthquake   8.80
# 23409  12/28/2016  12:38:51   36.9179   140.4262  Earthquake  10.00
# 23410  12/29/2016  22:30:19   -9.0283   118.6639  Earthquake  79.00
# 23411  12/30/2016  20:08:28   37.3973   141.4103  Earthquake  11.94
#
#        Depth Error  Depth Seismic Stations  Magnitude Magnitude Type  ...  \
# 23408          2.0                    33.0        5.5             ML  ...
# 23409          1.8                     NaN        5.9            MWW  ...
# 23410          1.8                     NaN        6.3            MWW  ...
# 23411          2.2                     NaN        5.5             MB  ...
#
#        Magnitude Seismic Stations  Azimuthal Gap  Horizontal Distance  \
# 23408                        18.0          48.58                0.129
# 23409                         NaN          91.00                0.992
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.shape
# Out:
# (23412, 21)

# %%
df.columns
# Out:
# Index(['Date', 'Time', 'Latitude', 'Longitude', 'Type', 'Depth', 'Depth Error',
#        'Depth Seismic Stations', 'Magnitude', 'Magnitude Type',
#        'Magnitude Error', 'Magnitude Seismic Stations', 'Azimuthal Gap',
#        'Horizontal Distance', 'Horizontal Error', 'Root Mean Square', 'ID',
#        'Source', 'Location Source', 'Magnitude Source', 'Status'],
#       dtype='object')

# %%
df.isnull()
# Out:
#         Date   Time  Latitude  Longitude   Type  Depth  Depth Error  \
# 0      False  False     False      False  False  False         True
# 1      False  False     False      False  False  False         True
# 2      False  False     False      False  False  False         True
# 3      False  False     False      False  False  False         True
# 4      False  False     False      False  False  False         True
# ...      ...    ...       ...        ...    ...    ...          ...
# 23407  False  False     False      False  False  False        False
# 23408  False  False     False      False  False  False        False
# 23409  False  False     False      False  False  False        False
# 23410  False  False     False      False  False  False        False
# 23411  False  False     False      False  False  False        False
#
#        Depth Seismic Stations  Magnitude  Magnitude Type  ...  \
# 0                        True      False           False  ...
# ...

# %%
df.isnull().sum()
# Out:
# Date                              0
# Time                              0
# Latitude                          0
# Longitude                         0
# Type                              0
# Depth                             0
# Depth Error                   18951
# Depth Seismic Stations        16315
# Magnitude                         0
# Magnitude Type                    3
# Magnitude Error               23085
# Magnitude Seismic Stations    20848
# Azimuthal Gap                 16113
# Horizontal Distance           21808
# Horizontal Error              22256
# Root Mean Square               6060
# ID                                0
# Source                            0
# Location Source                   0
# Magnitude Source                  0
# Status                            0
# dtype: int64

# %%
df.Date
# Out:
# 0        01/02/1965
# 1        01/04/1965
# 2        01/05/1965
# 3        01/08/1965
# 4        01/09/1965
#             ...
# 23407    12/28/2016
# 23408    12/28/2016
# 23409    12/28/2016
# 23410    12/29/2016
# 23411    12/30/2016
# Name: Date, Length: 23412, dtype: object

# %%
# Alternate syntax
df['Date']
# Out:
# 0        01/02/1965
# 1        01/04/1965
# 2        01/05/1965
# 3        01/08/1965
# 4        01/09/1965
#             ...
# 23407    12/28/2016
# 23408    12/28/2016
# 23409    12/28/2016
# 23410    12/29/2016
# 23411    12/30/2016
# Name: Date, Length: 23412, dtype: object

# %%
df['Magnitude Type']
# Out:
# 0         MW
# 1         MW
# 2         MW
# 3         MW
# 4         MW
#         ...
# 23407     ML
# 23408     ML
# 23409    MWW
# 23410    MWW
# 23411     MB
# Name: Magnitude Type, Length: 23412, dtype: object

# %%
df[['Latitude','Longitude','Type']]
# Out:
#        Latitude  Longitude        Type
# 0       19.2460   145.6160  Earthquake
# 1        1.8630   127.3520  Earthquake
# 2      -20.5790  -173.9720  Earthquake
# 3      -59.0760   -23.5570  Earthquake
# 4       11.9380   126.4270  Earthquake
# ...         ...        ...         ...
# 23407   38.3917  -118.8941  Earthquake
# 23408   38.3777  -118.8957  Earthquake
# 23409   36.9179   140.4262  Earthquake
# 23410   -9.0283   118.6639  Earthquake
# 23411   37.3973   141.4103  Earthquake
#
# [23412 rows x 3 columns]

# %%
df[['Latitude','Longitude','Type']].head()
# Out:
#    Latitude  Longitude        Type
# 0    19.246    145.616  Earthquake
# 1     1.863    127.352  Earthquake
# 2   -20.579   -173.972  Earthquake
# 3   -59.076    -23.557  Earthquake
# 4    11.938    126.427  Earthquake

# %%
# drop or delete a column 
df.drop(columns = 'Magnitude Error')
# Out:
#              Date      Time  Latitude  Longitude        Type   Depth  \
# 0      01/02/1965  13:44:18   19.2460   145.6160  Earthquake  131.60
# 1      01/04/1965  11:29:49    1.8630   127.3520  Earthquake   80.00
# 2      01/05/1965  18:05:58  -20.5790  -173.9720  Earthquake   20.00
# 3      01/08/1965  18:49:43  -59.0760   -23.5570  Earthquake   15.00
# 4      01/09/1965  13:32:50   11.9380   126.4270  Earthquake   15.00
# ...           ...       ...       ...        ...         ...     ...
# 23407  12/28/2016  08:22:12   38.3917  -118.8941  Earthquake   12.30
# 23408  12/28/2016  09:13:47   38.3777  -118.8957  Earthquake    8.80
# 23409  12/28/2016  12:38:51   36.9179   140.4262  Earthquake   10.00
# 23410  12/29/2016  22:30:19   -9.0283   118.6639  Earthquake   79.00
# 23411  12/30/2016  20:08:28   37.3973   141.4103  Earthquake   11.94
#
#        Depth Error  Depth Seismic Stations  Magnitude Magnitude Type  \
# ...

# %%
df
# Out:
#              Date      Time  Latitude  Longitude        Type   Depth  \
# 0      01/02/1965  13:44:18   19.2460   145.6160  Earthquake  131.60
# 1      01/04/1965  11:29:49    1.8630   127.3520  Earthquake   80.00
# 2      01/05/1965  18:05:58  -20.5790  -173.9720  Earthquake   20.00
# 3      01/08/1965  18:49:43  -59.0760   -23.5570  Earthquake   15.00
# 4      01/09/1965  13:32:50   11.9380   126.4270  Earthquake   15.00
# ...           ...       ...       ...        ...         ...     ...
# 23407  12/28/2016  08:22:12   38.3917  -118.8941  Earthquake   12.30
# 23408  12/28/2016  09:13:47   38.3777  -118.8957  Earthquake    8.80
# 23409  12/28/2016  12:38:51   36.9179   140.4262  Earthquake   10.00
# 23410  12/29/2016  22:30:19   -9.0283   118.6639  Earthquake   79.00
# 23411  12/30/2016  20:08:28   37.3973   141.4103  Earthquake   11.94
#
#        Depth Error  Depth Seismic Stations  Magnitude Magnitude Type  ...  \
# ...

# %%
df.drop(columns = 'Magnitude Error', inplace = True)

# %%
del df['Magnitude Seismic Stations']

# %%
df.shape
# Out:
# (23412, 19)

# %%
df.Depth.max()
# Out:
# 700.0

# %%
df.Depth.min()
# Out:
# -1.1

# %%
df.Depth.mode()
# Out:
# 0    10.0
# dtype: float64

# %%
df.Depth.mode()[0]
# Out:
# 10.0

# %%
df.Depth.std()
# Out:
# 122.65189771616214

# %%
df.Status.unique()
# Out:
# array(['Automatic', 'Reviewed'], dtype=object)

# %%
# nuinque gives count of unique values
df.Status.nunique()
# Out:
# 2

# %%
df.Type.unique()
# Out:
# array(['Earthquake', 'Nuclear Explosion', 'Explosion', 'Rock Burst'],
#       dtype=object)

# %%
df.Type.nunique()
# Out:
# 4

# %%
df.describe()
# Out:
#            Latitude     Longitude         Depth  Depth Error  \
# count  23412.000000  23412.000000  23412.000000  4461.000000
# mean       1.679033     39.639961     70.767911     4.993115
# std       30.113183    125.511959    122.651898     4.875184
# min      -77.080000   -179.997000     -1.100000     0.000000
# 25%      -18.653000    -76.349750     14.522500     1.800000
# 50%       -3.568500    103.982000     33.000000     3.500000
# 75%       26.190750    145.026250     54.000000     6.300000
# max       86.005000    179.998000    700.000000    91.295000
#
#        Depth Seismic Stations     Magnitude  Azimuthal Gap  \
# count             7097.000000  23412.000000    7299.000000
# mean               275.364098      5.882531      44.163532
# std                162.141631      0.423066      32.141486
# min                  0.000000      5.500000       0.000000
# 25%                146.000000      5.600000      24.100000
# ...

# %%
df[['Latitude','Longitude']]
# Out:
#        Latitude  Longitude
# 0       19.2460   145.6160
# 1        1.8630   127.3520
# 2      -20.5790  -173.9720
# 3      -59.0760   -23.5570
# 4       11.9380   126.4270
# ...         ...        ...
# 23407   38.3917  -118.8941
# 23408   38.3777  -118.8957
# 23409   36.9179   140.4262
# 23410   -9.0283   118.6639
# 23411   37.3973   141.4103
#
# [23412 rows x 2 columns]

# %%
df.Latitude.min()
# Out:
# -77.08

# %%
df[['Latitude','Longitude']].sort_values(by='Latitude')
# Out:
#        Latitude  Longitude
# 21304   -77.080   -148.864
# 11457   -72.448    174.838
# 18716   -67.034    111.199
# 4237    -66.448    -82.584
# 5717    -65.721   -175.714
# ...         ...        ...
# 14288    85.686     86.034
# 14255    85.734     84.439
# 14294    85.735     84.906
# 2910     85.992     30.825
# 15812    86.005     31.595
#
# [23412 rows x 2 columns]

# %%
df[['Latitude','Longitude']].sort_values(by='Latitude', ascending = False)
# Out:
#        Latitude  Longitude
# 15812    86.005     31.595
# 2910     85.992     30.825
# 14294    85.735     84.906
# 14255    85.734     84.439
# 14288    85.686     86.034
# ...         ...        ...
# 5717    -65.721   -175.714
# 4237    -66.448    -82.584
# 18716   -67.034    111.199
# 11457   -72.448    174.838
# 21304   -77.080   -148.864
#
# [23412 rows x 2 columns]

# %%
df.Type.nunique()
# Out:
# 4

# %%
df.Type.value_counts()
# Out:
# Earthquake           23232
# Nuclear Explosion      175
# Explosion                4
# Rock Burst               1
# Name: Type, dtype: int64

# %%
# Alternate 
df['Type'].value_counts()
# Out:
# Earthquake           23232
# Nuclear Explosion      175
# Explosion                4
# Rock Burst               1
# Name: Type, dtype: int64

# %%
# Filtering the dataframe

df[df['Type'] == 'Nuclear Explosion']
# Out:
#              Date      Time   Latitude   Longitude               Type  Depth  \
# 565    12/20/1966  15:30:01  37.302167 -116.408333  Nuclear Explosion    1.2
# 897    04/26/1968  15:00:02  37.295333 -116.455667  Nuclear Explosion    1.2
# 1129   12/19/1968  16:30:01  37.231500 -116.473667  Nuclear Explosion    1.4
# 1380   09/16/1969  14:30:01  37.314167 -116.460667  Nuclear Explosion    1.2
# 1532   03/26/1970  19:00:01  37.300500 -116.534167  Nuclear Explosion    1.2
# ...           ...       ...        ...         ...                ...    ...
# 11963  06/10/1994  06:25:58  41.527000   88.710000  Nuclear Explosion    0.0
# 12142  10/07/1994  03:25:58  41.662000   88.753000  Nuclear Explosion    0.0
# 12450  05/15/1995  04:05:58  41.603000   88.820000  Nuclear Explosion    0.0
# 12613  08/17/1995  00:59:58  41.559000   88.800000  Nuclear Explosion    0.0
# 13054  06/08/1996  02:55:58  41.657000   88.690000  Nuclear Explosion    0.0
#
# ...

# %%
df[df['Type'] == 'Nuclear Explosion'].shape
# Out:
# (175, 19)

# %%
df[(df['Type'] == 'Nuclear Explosion') | (df['Type'] == 'Explosion')]
# Out:
#              Date      Time   Latitude   Longitude               Type  Depth  \
# 565    12/20/1966  15:30:01  37.302167 -116.408333  Nuclear Explosion    1.2
# 897    04/26/1968  15:00:02  37.295333 -116.455667  Nuclear Explosion    1.2
# 1129   12/19/1968  16:30:01  37.231500 -116.473667  Nuclear Explosion    1.4
# 1380   09/16/1969  14:30:01  37.314167 -116.460667  Nuclear Explosion    1.2
# 1532   03/26/1970  19:00:01  37.300500 -116.534167  Nuclear Explosion    1.2
# ...           ...       ...        ...         ...                ...    ...
# 11963  06/10/1994  06:25:58  41.527000   88.710000  Nuclear Explosion    0.0
# 12142  10/07/1994  03:25:58  41.662000   88.753000  Nuclear Explosion    0.0
# 12450  05/15/1995  04:05:58  41.603000   88.820000  Nuclear Explosion    0.0
# 12613  08/17/1995  00:59:58  41.559000   88.800000  Nuclear Explosion    0.0
# 13054  06/08/1996  02:55:58  41.657000   88.690000  Nuclear Explosion    0.0
#
# ...

# %%
df[(df['Type'] == 'Nuclear Explosion') | (df['Type'] == 'Explosion')].shape
# Out:
# (179, 19)

# %%
df[(df['Type'] == 'Nuclear Explosion') | (df['Type'] == 'Explosion')]['Magnitude']
# Out:
# 565      5.62
# 897      5.63
# 1129     5.52
# 1380     5.82
# 1532     5.54
#          ...
# 11963    5.80
# 12142    6.00
# 12450    6.10
# 12613    6.00
# 13054    5.90
# Name: Magnitude, Length: 179, dtype: float64

# %%
df[(df['Type'] == 'Nuclear Explosion') | (df['Type'] == 'Explosion')][df.Magnitude > 6]
# Out:
# C:\Users\hp\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#              Date      Time  Latitude  Longitude               Type  Depth  \
# 2797   07/23/1973  01:22:58    49.986     78.853  Nuclear Explosion    0.0
# 2859   09/12/1973  06:59:54    73.302     55.161  Nuclear Explosion    0.0
# 2897   10/27/1973  06:59:57    70.779     54.177  Nuclear Explosion    0.0
# 3218   08/29/1974  09:59:55    73.366     55.094  Nuclear Explosion    0.0
# 3286   11/02/1974  04:59:57    70.817     54.063  Nuclear Explosion    0.0
# 3593   08/23/1975  08:59:58    73.369     54.641          Explosion    0.0
# 3661   10/18/1975  08:59:56    70.843     53.690  Nuclear Explosion    0.0
# 3663   10/21/1975  11:59:57    73.351     55.078  Nuclear Explosion    0.0
# 5198   06/23/1979  02:56:58    49.918     78.915  Nuclear Explosion    0.0
# ...

# %%
BigEarthquake = df[(df['Type'] == 'Nuclear Explosion') | (df['Type'] == 'Explosion')][df.Magnitude > 6].copy()
# Out:
# C:\Users\hp\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.

# %%
BigEarthquake
# Out:
#              Date      Time  Latitude  Longitude               Type  Depth  \
# 2797   07/23/1973  01:22:58    49.986     78.853  Nuclear Explosion    0.0
# 2859   09/12/1973  06:59:54    73.302     55.161  Nuclear Explosion    0.0
# 2897   10/27/1973  06:59:57    70.779     54.177  Nuclear Explosion    0.0
# 3218   08/29/1974  09:59:55    73.366     55.094  Nuclear Explosion    0.0
# 3286   11/02/1974  04:59:57    70.817     54.063  Nuclear Explosion    0.0
# 3593   08/23/1975  08:59:58    73.369     54.641          Explosion    0.0
# 3661   10/18/1975  08:59:56    70.843     53.690  Nuclear Explosion    0.0
# 3663   10/21/1975  11:59:57    73.351     55.078  Nuclear Explosion    0.0
# 5198   06/23/1979  02:56:58    49.918     78.915  Nuclear Explosion    0.0
# 5234   08/04/1979  03:56:57    49.901     78.959  Nuclear Explosion    0.0
# 5248   08/18/1979  02:51:57    49.971     79.010  Nuclear Explosion    0.0
# ...

# %%
BigEarthquake.reset_index(inplace = True)

# %%
BigEarthquake
# Out:
#     index        Date      Time  Latitude  Longitude               Type  \
# 0    2797  07/23/1973  01:22:58    49.986     78.853  Nuclear Explosion
# 1    2859  09/12/1973  06:59:54    73.302     55.161  Nuclear Explosion
# 2    2897  10/27/1973  06:59:57    70.779     54.177  Nuclear Explosion
# 3    3218  08/29/1974  09:59:55    73.366     55.094  Nuclear Explosion
# 4    3286  11/02/1974  04:59:57    70.817     54.063  Nuclear Explosion
# 5    3593  08/23/1975  08:59:58    73.369     54.641          Explosion
# 6    3661  10/18/1975  08:59:56    70.843     53.690  Nuclear Explosion
# 7    3663  10/21/1975  11:59:57    73.351     55.078  Nuclear Explosion
# 8    5198  06/23/1979  02:56:58    49.918     78.915  Nuclear Explosion
# 9    5234  08/04/1979  03:56:57    49.901     78.959  Nuclear Explosion
# 10   5248  08/18/1979  02:51:57    49.971     79.010  Nuclear Explosion
# 11   5388  12/23/1979  04:56:58    49.964     78.827  Nuclear Explosion
# ...

# %%
# Slicing the dataframe

BigEarthquake.iloc[:10,:7]
# Out:
#    index        Date      Time  Latitude  Longitude               Type  Depth
# 0   2797  07/23/1973  01:22:58    49.986     78.853  Nuclear Explosion    0.0
# 1   2859  09/12/1973  06:59:54    73.302     55.161  Nuclear Explosion    0.0
# 2   2897  10/27/1973  06:59:57    70.779     54.177  Nuclear Explosion    0.0
# 3   3218  08/29/1974  09:59:55    73.366     55.094  Nuclear Explosion    0.0
# 4   3286  11/02/1974  04:59:57    70.817     54.063  Nuclear Explosion    0.0
# 5   3593  08/23/1975  08:59:58    73.369     54.641          Explosion    0.0
# 6   3661  10/18/1975  08:59:56    70.843     53.690  Nuclear Explosion    0.0
# 7   3663  10/21/1975  11:59:57    73.351     55.078  Nuclear Explosion    0.0
# 8   5198  06/23/1979  02:56:58    49.918     78.915  Nuclear Explosion    0.0
# 9   5234  08/04/1979  03:56:57    49.901     78.959  Nuclear Explosion    0.0

# %%
BigEarthquake.loc[9]
# Out:
# index                                  5234
# Date                             08/04/1979
# Time                               03:56:57
# Latitude                             49.901
# Longitude                            78.959
# Type                      Nuclear Explosion
# Depth                                     0
# Depth Error                             NaN
# Depth Seismic Stations                  NaN
# Magnitude                               6.1
# Magnitude Type                           MB
# Azimuthal Gap                           NaN
# Horizontal Distance                     NaN
# Horizontal Error                        NaN
# Root Mean Square                        NaN
# ID                               USP000127H
# Source                                   US
# Location Source                          US
# Magnitude Source                         US
# Status                             Reviewed
# Name: 9, dtype: object

# %%
BigEarthquake.loc[9,'Type'] = 'Volcanic Eruption'

# %%
BigEarthquake.iloc[:10,:7]
# Out:
#    index        Date      Time  Latitude  Longitude               Type  Depth
# 0   2797  07/23/1973  01:22:58    49.986     78.853  Nuclear Explosion    0.0
# 1   2859  09/12/1973  06:59:54    73.302     55.161  Nuclear Explosion    0.0
# 2   2897  10/27/1973  06:59:57    70.779     54.177  Nuclear Explosion    0.0
# 3   3218  08/29/1974  09:59:55    73.366     55.094  Nuclear Explosion    0.0
# 4   3286  11/02/1974  04:59:57    70.817     54.063  Nuclear Explosion    0.0
# 5   3593  08/23/1975  08:59:58    73.369     54.641          Explosion    0.0
# 6   3661  10/18/1975  08:59:56    70.843     53.690  Nuclear Explosion    0.0
# 7   3663  10/21/1975  11:59:57    73.351     55.078  Nuclear Explosion    0.0
# 8   5198  06/23/1979  02:56:58    49.918     78.915  Nuclear Explosion    0.0
# 9   5234  08/04/1979  03:56:57    49.901     78.959  Volcanic Eruption    0.0

# %%
BigEarthquake['New Column'] = BigEarthquake.Latitude + 100

# %%
BigEarthquake.loc[[9]]
# Out:
#    index        Date      Time  Latitude  Longitude               Type  Depth  \
# 9   5234  08/04/1979  03:56:57    49.901     78.959  Volcanic Eruption    0.0
#
#    Depth Error  Depth Seismic Stations  Magnitude  ... Azimuthal Gap  \
# 9          NaN                     NaN        6.1  ...           NaN
#
#    Horizontal Distance  Horizontal Error  Root Mean Square          ID Source  \
# 9                  NaN               NaN               NaN  USP000127H     US
#
#   Location Source Magnitude Source    Status New Column
# 9              US               US  Reviewed    149.901
#
# [1 rows x 21 columns]

# %%
BigEarthquake
# Out:
#     index        Date      Time  Latitude  Longitude               Type  \
# 0    2797  07/23/1973  01:22:58    49.986     78.853  Nuclear Explosion
# 1    2859  09/12/1973  06:59:54    73.302     55.161  Nuclear Explosion
# 2    2897  10/27/1973  06:59:57    70.779     54.177  Nuclear Explosion
# 3    3218  08/29/1974  09:59:55    73.366     55.094  Nuclear Explosion
# 4    3286  11/02/1974  04:59:57    70.817     54.063  Nuclear Explosion
# 5    3593  08/23/1975  08:59:58    73.369     54.641          Explosion
# 6    3661  10/18/1975  08:59:56    70.843     53.690  Nuclear Explosion
# 7    3663  10/21/1975  11:59:57    73.351     55.078  Nuclear Explosion
# 8    5198  06/23/1979  02:56:58    49.918     78.915  Nuclear Explosion
# 9    5234  08/04/1979  03:56:57    49.901     78.959  Volcanic Eruption
# 10   5248  08/18/1979  02:51:57    49.971     79.010  Nuclear Explosion
# 11   5388  12/23/1979  04:56:58    49.964     78.827  Nuclear Explosion
# ...
